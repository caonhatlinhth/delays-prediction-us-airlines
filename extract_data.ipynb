# %%
import os
import pandas as pd

# List of years for which you want to process files
desired_years = ['2018', '2019', '2021', '2022', '2023']

# List of airlines to filter
desired_airlines = ['9E', 'OH', 'YV', 'QX', 'PT', 'ZW', 'G7', 'C5', 'EM', 'KS', '9K', 'AS', 'NK', 'F9', 'G4', 'HA']

# Columns to extract
columns = [
    'Year', 'Month', 'DayOfWeek', 'Operating_Airline', 'Tail_Number',
    'Origin', 'OriginState', 'Dest', 'DestState', 'DepDelayMinutes', 
    'DepDel15', 'DepTimeBlk', 'TaxiOut', 'WheelsOff', 'WheelsOn', 'TaxiIn',
    'ArrDel15', 'ArrDelayMinutes', 'ArrTimeBlk', 'Distance',
    'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'DistanceGroup'
]

# Get the current working directory (folder containing the ipynb file)
data_folder_path = os.getcwd()

# Initialize an empty DataFrame to store the combined data
combined_df = pd.DataFrame()

# Iterate over the files
for file_name in os.listdir(data_folder_path):
    if file_name.endswith('.csv'):
        print("Processing file:", file_name)  # Add this line
        parts = file_name.split('_')
        year = parts[0]
        month = int(parts[1])  # Convert month to integer
        
        if year in desired_years:
            if month >= 1 and month <= 12:
                # Read the file into a DataFrame
                file_path = os.path.join(data_folder_path, file_name)
                df = pd.read_csv(file_path)
                
                # Filter by desired airlines
                df = df[df['Operating_Airline'].isin(desired_airlines)]
                
                # Extract only the desired columns
                df = df[columns]
                
                # Add 'Year' and 'Month' columns to the DataFrame
                df['Year'] = year
                df['Month'] = month
                
                # Concatenate the DataFrame to the combined DataFrame
                combined_df = pd.concat([combined_df, df], ignore_index=True)

# Save the combined data to a new CSV file
combined_data_file = os.path.join(data_folder_path, 'combined_data_mkt.csv')
combined_df.to_csv(combined_data_file, index=False)

print(f"Combined data saved to {combined_data_file}")
# Out:
# Processing file: 2018_10_analyzed.csv
# Processing file: 2018_11_analyzed.csv
# Processing file: 2018_12_analyzed.csv
# Processing file: 2018_1_analyzed.csv
# Processing file: 2018_2_analyzed.csv
# Processing file: 2018_3_analyzed.csv
# Processing file: 2018_4_analyzed.csv
# Processing file: 2018_5_analyzed.csv
# Processing file: 2018_6_analyzed.csv
# Processing file: 2018_7_analyzed.csv
# Processing file: 2018_8_analyzed.csv
# Processing file: 2018_9_analyzed.csv
# Processing file: 2019_10_analyzed.csv
# Processing file: 2019_11_analyzed.csv
# Processing file: 2019_12_analyzed.csv
# Processing file: 2019_1_analyzed.csv
# Processing file: 2019_2_analyzed.csv
# Processing file: 2019_3_analyzed.csv
# Processing file: 2019_4_analyzed.csv
# Processing file: 2019_5_analyzed.csv
# Processing file: 2019_6_analyzed.csv
# Processing file: 2019_7_analyzed.csv
# Processing file: 2019_8_analyzed.csv
# Processing file: 2019_9_analyzed.csv
# Processing file: 2020_10_analyzed.csv
# Processing file: 2020_11_analyzed.csv
# Processing file: 2020_12_analyzed.csv
# Processing file: 2020_1_analyzed.csv
# Processing file: 2020_2_analyzed.csv
# Processing file: 2020_3_analyzed.csv
# Processing file: 2020_4_analyzed.csv
# Processing file: 2020_5_analyzed.csv
# Processing file: 2020_6_analyzed.csv
# Processing file: 2020_7_analyzed.csv
# Processing file: 2020_8_analyzed.csv
# Processing file: 2020_9_analyzed.csv
# Processing file: 2021_10_analyzed.csv
# Processing file: 2021_11_analyzed.csv
# Processing file: 2021_12_analyzed.csv
# Processing file: 2021_1_analyzed.csv
# Processing file: 2021_2_analyzed.csv
# Processing file: 2021_3_analyzed.csv
# Processing file: 2021_4_analyzed.csv
# Processing file: 2021_5_analyzed.csv
# Processing file: 2021_6_analyzed.csv
# Processing file: 2021_7_analyzed.csv
# Processing file: 2021_8_analyzed.csv
# Processing file: 2021_9_analyzed.csv
# Processing file: 2022_10_analyzed.csv
# Processing file: 2022_11_analyzed.csv
# Processing file: 2022_12_analyzed.csv
# Processing file: 2022_1_analyzed.csv
# Processing file: 2022_2_analyzed.csv
# Processing file: 2022_3_analyzed.csv
# Processing file: 2022_4_analyzed.csv
# Processing file: 2022_5_analyzed.csv
# Processing file: 2022_6_analyzed.csv
# Processing file: 2022_7_analyzed.csv
# Processing file: 2022_8_analyzed.csv
# Processing file: 2022_9_analyzed.csv
# Processing file: 2023_1_analyzed.csv
# Processing file: 2023_2_analyzed.csv
# Processing file: 2023_3_analyzed.csv
# Processing file: 2023_4_analyzed.csv
# Combined data saved to e:\Data\combined_data_mkt.csv
